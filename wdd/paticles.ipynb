# %%
import sys
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline


cv.__version__
# Out:
# '4.6.0'

# %%
img = cv.imread("c01_IMG_7510.jpg")

# %%
# # check if file found
# if img is None:
#     sys.exit("Could not read the image.")

# # display file
# cv.imshow("Display window", img)

# # pause execution here by waiting for a user to press a key
# k = cv.waitKey(0)

# # if user typed s save file as PNG file
# if k == ord("s"):
#     cv.imwrite("test.png", img)

# cv.destroyAllWindows()

# %%
imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# imgRGB = toRGB(img)
plt.figure()

plt.imshow(imgRGB)
plt.title("title")
plt.show()

# %%
imgGray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

plt.imshow(imgGray)
plt.title("Gray")
plt.show()

# %%
ret1, thresh1 = cv.threshold(imgGray, 50, 255, cv.THRESH_BINARY)

img2 = cv.cvtColor(thresh1, cv.COLOR_GRAY2RGB)

plt.imshow(img2)
plt.title("Thresh")
plt.show()

# %%
def showWithMatplotlib(color_img, title, pos):
    """Shows an image using matplotlib capabilities"""

    # Convert BGR image to RGB
    img_RGB = color_img[:, :, ::-1]

    ax = plt.subplot(2, 3, pos)
    plt.imshow(img_RGB)
    ax.set_title(title)
    plt.axis('off')

# %%
fig = plt.figure(figsize=(15, 7))
plt.suptitle("Adaptive thresholding", fontsize=14, fontweight='bold')
fig.patch.set_facecolor('silver')

ret1, threshB1 = cv.threshold(imgGray, 50, 255, cv.THRESH_BINARY)

thresh1 = cv.adaptiveThreshold(imgGray, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 11, 2)
thresh2 = cv.adaptiveThreshold(imgGray, 255, cv.ADAPTIVE_THRESH_MEAN_C, cv.THRESH_BINARY, 31, 3)
thresh3 = cv.adaptiveThreshold(imgGray, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 11, 2)
thresh4 = cv.adaptiveThreshold(imgGray, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 31, 3)

showWithMatplotlib(cv.cvtColor(imgGray, cv.COLOR_GRAY2BGR), "gray img", 1)
showWithMatplotlib(cv.cvtColor(threshB1, cv.COLOR_GRAY2BGR), "method=THRESH_BINARY=50", 4)

showWithMatplotlib(cv.cvtColor(thresh1, cv.COLOR_GRAY2BGR), "method=THRESH_MEAN_C, blockSize=11, C=2", 2)
showWithMatplotlib(cv.cvtColor(thresh2, cv.COLOR_GRAY2BGR), "method=THRESH_MEAN_C, blockSize=31, C=3", 3)
showWithMatplotlib(cv.cvtColor(thresh3, cv.COLOR_GRAY2BGR), "method=GAUSSIAN_C, blockSize=11, C=2", 5)
showWithMatplotlib(cv.cvtColor(thresh4, cv.COLOR_GRAY2BGR), "method=GAUSSIAN_C, blockSize=31, C=3", 6)
